# %%
from dask.distributed import Client
from dask_yarn import YarnCluster

cluster = YarnCluster(worker_memory='16GiB')
client = Client(cluster)
# Out:
# /opt/conda/miniconda3/lib/python3.10/site-packages/dask_yarn/core.py:16: FutureWarning: format_bytes is deprecated and will be removed in a future release. Please use dask.utils.format_bytes instead.
#   from distributed.utils import (
# /opt/conda/miniconda3/lib/python3.10/site-packages/dask_yarn/core.py:16: FutureWarning: parse_timedelta is deprecated and will be removed in a future release. Please use dask.utils.parse_timedelta instead.
#   from distributed.utils import (
# 23/10/22 22:35:42 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at dask-m.us-central1-f.c.galvanic-ripsaw-376002.internal./10.128.0.34:8032
# 23/10/22 22:35:42 INFO client.AHSProxy: Connecting to Application History server at dask-m.us-central1-f.c.galvanic-ripsaw-376002.internal./10.128.0.34:10200
# 23/10/22 22:35:43 INFO skein.Driver: Driver started, listening on 44969
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.anaconda.skein.shaded.com.google.protobuf.UnsafeUtil (file:/opt/conda/miniconda3/lib/python3.10/site-packages/skein/java/skein.jar) to field java.nio.Buffer.address
# WARNING: Please consider reporting this to the maintainers of com.anaconda.skein.shaded.com.google.protobuf.UnsafeUtil
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 23/10/22 22:35:43 INFO conf.Configuration: resource-types.xml not found
# 23/10/22 22:35:43 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 23/10/22 22:35:43 INFO skein.Driver: Uploading application resources to hdfs://dask-m/user/root/.skein/application_1698013795658_0001
# 23/10/22 22:35:44 INFO skein.Driver: Submitting application...
# 23/10/22 22:35:45 INFO impl.YarnClientImpl: Submitted application application_1698013795658_0001

# %%
# %load_ext autoreload
# %autoreload 2
from solardatatools.dataio import load_cassandra_data
from solardatatools import DataHandler
from statistical_clear_sky import SCSF

# %%
import dask

@dask.delayed
def pull_and_run(site_id):
    df = load_cassandra_data(site_id, cluster_ip="54.176.95.208")
    dh = DataHandler(df, convert_to_ts=True)
    dh.run_pipeline(power_col='ac_power_01')
    return dh.report(return_values=True)

# %%
results = []
site_ids = ["TAAJ01021775", "001C4B0008A5", "TABG01081601"]
for si in site_ids:
    results.append(pull_and_run(si))
dask.compute(results)
# Out:
# ([{'length': 4.46027397260274,
#    'capacity': 7.102129936218261,
#    'sampling': 5,
#    'quality score': 0.6750614250614251,
#    'clearness score': 0.35565110565110564,
#    'inverter clipping': False,
#    'clipped fraction': 0.007985257985257985,
#    'capacity change': False,
#    'data quality warning': True,
#    'time shift correction': False,
#    'time zone correction': 0},
#   {'length': 1.082191780821918,
#    'capacity': 3.001,
#    'sampling': 15,
#    'quality score': 0.9189873417721519,
#    'clearness score': 0.5417721518987342,
#    'inverter clipping': False,
#    'clipped fraction': 0.007594936708860759,
#    'capacity change': False,
#    'data quality warning': False,
#    'time shift correction': False,
#    'time zone correction': 0},
#   {'length': 5.391780821917808,
#    'capacity': 4.88670015335083,
#    'sampling': 5,
#    'quality score': 0.9664634146341463,
#    'clearness score': 0.5182926829268293,
#    'inverter clipping': False,
#    'clipped fraction': 0.002540650406504065,
#    'capacity change': True,
#    'data quality warning': True,
#    'time shift correction': False,
#    'time zone correction': 0}],)
