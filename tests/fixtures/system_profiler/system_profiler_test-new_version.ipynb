# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pandas as pd
from pathlib import Path
import seaborn as sns
import numpy as np
# PVInsight Code Imports
from pathlib import Path
sdt_path = str(Path.cwd().parent.parent.parent)
sys.path.append(sdt_path)
from solardatatools import DataHandler
from solardatatools.dataio import get_pvdaq_data

# %%
fn = 'data_handler_input.csv'
if os.path.isfile(fn):
    data_frame = pd.read_csv(fn, index_col=0)
else:
    data_frame = get_pvdaq_data(sysid=1199, year=[2015, 2016, 2017], api_key='DEMO_KEY', standardize=False)
    data_frame.to_csv(fn)

# %%
data_frame["Date-Time"] = pd.to_datetime(data_frame["Date-Time"])

# %%
df1 = data_frame.set_index("Date-Time")
df1
# Out:
#                      SiteID    ac_power    dc_power  inv1_ac_power  \
# Date-Time
# 2015-01-01 07:20:32    1199    0.000000    0.000000       0.000000
# 2015-01-01 07:25:33    1199    0.000000    0.000000       0.000000
# 2015-01-01 07:30:34    1199    5.361111   35.755449       0.000000
# 2015-01-01 07:35:34    1199   71.482142  305.379709       8.714286
# 2015-01-01 07:40:34    1199  175.196428  493.599934      28.875000
# ...                     ...         ...         ...            ...
# 2017-12-31 16:50:42    1199    4.303571   31.739720       2.142857
# 2017-12-31 16:55:42    1199    0.000000    0.000000       0.000000
# 2017-12-31 17:00:42    1199    0.000000    0.000000       0.000000
# 2017-12-31 17:05:42    1199    0.000000    0.000000       0.000000
# 2017-12-31 17:10:42    1199    0.000000    0.000000       0.000000
#
#                      inv1_dc_current  inv1_dc_power  inv1_dc_voltage  \
# Date-Time
# 2015-01-01 07:20:32         0.000000       0.000000       289.200000
# 2015-01-01 07:25:33         0.000000       0.000000       289.000000
# 2015-01-01 07:30:34         0.000000       0.000000       305.875000
# 2015-01-01 07:35:34         0.126000      37.836000       300.285714
# 2015-01-01 07:40:34         0.291375      75.174750       258.000000
# ...                              ...            ...              ...
# 2017-12-31 16:50:42         0.033000      10.390286       314.857143
# 2017-12-31 16:55:42         0.000000       0.000000       297.625000
# 2017-12-31 17:00:42         0.000000       0.000000       303.875000
# 2017-12-31 17:05:42         0.000000       0.000000       276.125000
# 2017-12-31 17:10:42         0.000000       0.000000       209.500000
#
#                      inv1_temp  inv2_ac_power  inv2_dc_current  ...  \
# Date-Time                                                       ...
# 2015-01-01 07:20:32  16.900000       0.000000         0.000000  ...
# 2015-01-01 07:25:33  16.900000       0.000000         0.000000  ...
# 2015-01-01 07:30:34  16.987500       0.125000         0.007250  ...
# 2015-01-01 07:35:34  17.500000      13.285714         0.195714  ...
# 2015-01-01 07:40:34  17.600000      33.000000         0.309000  ...
# ...                        ...            ...              ...  ...
# 2017-12-31 16:50:42  29.328571       0.000000         0.000000  ...
# 2017-12-31 16:55:42  28.900000       0.000000         0.000000  ...
# 2017-12-31 17:00:42  28.900000       0.000000         0.000000  ...
# 2017-12-31 17:05:42  28.450000       0.000000         0.000000  ...
# 2017-12-31 17:10:42  28.300000       0.000000         0.000000  ...
#
#                      inv6_ac_power  inv6_dc_current  inv6_dc_power  \
# Date-Time
# 2015-01-01 07:20:32       0.000000         0.000000       0.000000
# 2015-01-01 07:25:33       0.000000         0.000000       0.000000
# 2015-01-01 07:30:34       0.250000         0.012625       3.954781
# 2015-01-01 07:35:34       9.428571         0.153143      42.858162
# 2015-01-01 07:40:34      27.250000         0.284375      72.515625
# ...                            ...              ...            ...
# 2017-12-31 16:50:42       0.285714         0.014286       4.367434
# 2017-12-31 16:55:42       0.000000         0.000000       0.000000
# 2017-12-31 17:00:42       0.000000         0.000000       0.000000
# 2017-12-31 17:05:42       0.000000         0.000000       0.000000
# 2017-12-31 17:10:42       0.000000         0.000000       0.000000
#
#                      inv6_dc_voltage  inv6_temp  inv7_ac_power  \
# Date-Time
# 2015-01-01 07:20:32       277.600000    16.9000       0.000000
# 2015-01-01 07:25:33       301.125000    16.9000       0.000000
# 2015-01-01 07:30:34       313.250000    16.9875       1.111111
# 2015-01-01 07:35:34       279.857143    17.5000       7.428571
# 2015-01-01 07:40:34       255.000000    17.6000      20.428571
# ...                              ...        ...            ...
# 2017-12-31 16:50:42       305.714286    29.5000       0.000000
# 2017-12-31 16:55:42       287.625000    28.9750       0.000000
# 2017-12-31 17:00:42       307.250000    28.9000       0.000000
# 2017-12-31 17:05:42       273.625000    28.5250       0.000000
# 2017-12-31 17:10:42       201.500000    28.3000       0.000000
#
#                      inv7_dc_current  inv7_dc_power  inv7_dc_voltage  \
# Date-Time
# 2015-01-01 07:20:32         0.000000       0.000000       279.000000
# 2015-01-01 07:25:33         0.000000       0.000000       300.285714
# 2015-01-01 07:30:34         0.022889       6.813292       297.666667
# 2015-01-01 07:35:34         0.122143      35.613409       291.571429
# 2015-01-01 07:40:34         0.251857      64.511372       256.142857
# ...                              ...            ...              ...
# 2017-12-31 16:50:42         0.000000       0.000000       311.375000
# 2017-12-31 16:55:42         0.000000       0.000000       296.750000
# 2017-12-31 17:00:42         0.000000       0.000000       300.875000
# 2017-12-31 17:05:42         0.000000       0.000000       266.714286
# 2017-12-31 17:10:42         0.000000       0.000000       191.000000
#
#                      inv7_temp
# Date-Time
# 2015-01-01 07:20:32  15.700000
# 2015-01-01 07:25:33  15.700000
# 2015-01-01 07:30:34  15.700000
# 2015-01-01 07:35:34  15.785714
# 2015-01-01 07:40:34  16.300000
# ...                        ...
# 2017-12-31 16:50:42  27.525000
# 2017-12-31 16:55:42  27.375000
# 2017-12-31 17:00:42  27.075000
# 2017-12-31 17:05:42  26.828571
# 2017-12-31 17:10:42  26.700000
#
# [160837 rows x 38 columns]

# %%
df1.index
# Out:
# DatetimeIndex(['2015-01-01 07:20:32', '2015-01-01 07:25:33',
#                '2015-01-01 07:30:34', '2015-01-01 07:35:34',
#                '2015-01-01 07:40:34', '2015-01-01 07:45:34',
#                '2015-01-01 07:50:34', '2015-01-01 07:55:35',
#                '2015-01-01 08:00:37', '2015-01-01 08:05:37',
#                ...
#                '2017-12-31 16:25:39', '2017-12-31 16:30:40',
#                '2017-12-31 16:35:41', '2017-12-31 16:40:42',
#                '2017-12-31 16:45:42', '2017-12-31 16:50:42',
#                '2017-12-31 16:55:42', '2017-12-31 17:00:42',
#                '2017-12-31 17:05:42', '2017-12-31 17:10:42'],
#               dtype='datetime64[ns]', name='Date-Time', length=160837, freq=None)

# %%
# dh = DataHandler(data_frame, datetime_col="Date-Time")
dh = DataHandler(df1)
# dh.fix_dst()
dh.run_pipeline(power_col='ac_power', fix_shifts=True, correct_tz=False, solver="MOSEK", c2=1e5)
# Out:
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# Starting estimate components
# 12.825686594164354
# total time: 9.05 seconds
# --------------------------------
# Breakdown
# --------------------------------
# Preprocessing              2.77s
# Cleaning                   4.85s
# Filtering/Summarizing      1.43s
#     Data quality           0.25s
#     Clear day detect       0.30s
#     Clipping detect        0.19s
#     Capacity change detect 0.70s

# %%
dh.report()
# Out:
# -----------------
# DATA SET REPORT
# -----------------
# length               3.00 years
# capacity estimate    40.99 kW
# data sampling        5 minutes
# quality score        0.96
# clearness score      0.18
# inverter clipping    False
# clipped fraction     0.00
# capacity changes     False
# data quality warning True
# time shift errors    False
# time zone errors     False

# %%
dh.plot_heatmap("raw");

# %%
dh.plot_heatmap("filled");

# %%
dh.time_shift_analysis.plot_optimization();

# %%
dh.time_shift_analysis.normalized_holdout_error
# Out:
# array([1.        , 0.92769831, 0.80339308, 0.6415472 , 0.40695332,
#        0.26553854, 0.        , 0.01259848, 0.01263804, 0.0126406 ,
#        0.01264268])

# %%
dh.plot_time_shift_analysis_results();

# %%
dh.plot_time_shift_analysis_results();

# %%
dh.time_shift_analysis.c1_vals
# Out:
# array([  0.1       ,   0.19952623,   0.39810717,   0.79432823,
#          1.58489319,   3.16227766,   6.30957344,  12.58925412,
#         25.11886432,  50.11872336, 100.        ])

# %%
dh.time_shift_analysis.plot_optimization();

# %%
dh.plot_heatmap('filled');

# %%
dh.plot_data_quality_scatter();

# %%
dh.plot_capacity_change_analysis();

# %%
dh.plot_density_signal();

# %%
dh.plot_clipping();

# %%
dh.plot_daily_max_cdf_and_pdf();

# %%
dh.report()
# Out:
# -----------------
# DATA SET REPORT
# -----------------
# length               3.00 years
# capacity estimate    40.99 kW
# data sampling        5 minutes
# quality score        0.96
# clearness score      0.18
# inverter clipping    False
# clipped fraction     0.00
# capacity changes     False
# data quality warning True
# time shift errors    False
# time zone errors     False

# %%
dh.daytime_analysis.calculate_times(data=dh.filled_data_matrix, plot=True);

# %%
dh.setup_location_and_orientation_estimation(-5)

# %%
dh.estimate_latitude()
# Out:
# 37.29394243482891

# %%
dh.estimate_latitude()
# Out:
# 37.29394243482891

# %%
dh.estimate_latitude()
# Out:
# 37.29394243482891

# %%
dh.estimate_longitude()
# Out:
# -77.06787988773452

# %%
dh.estimate_longitude()
# Out:
# -77.06787988773452

# %%
dh.estimate_longitude()
# Out:
# -77.06787988773452

# %%
dh.estimate_longitude()
# Out:
# -77.06787988773452

# %%
# actual site location 
lat_actual = 39.4856
lon_actual = -76.6636
# run orientation estimation based on actual location
dh.estimate_orientation(latitude=lat_actual, longitude=lon_actual)
# Out:
# (22.369206764959632, 0.5894994245424108)

# %%
dh.estimate_orientation(latitude=lat_actual, longitude=lon_actual)
# Out:
# (22.36920990288654, 0.5894992147238165)

# %%
dh.estimate_orientation(latitude=lat_actual, longitude=lon_actual)
# Out:
# (22.369207034640237, 0.5894987367761861)

# %%
dh.estimate_orientation(latitude=lat_actual, longitude=lon_actual)
# Out:
# (22.3692311924758, 0.5894977458691655)

# %%
dh.estimate_orientation()
# Out:
# (20.354129137567757, -0.4658443120243453)

# %%
dh.estimate_location_and_orientation()
# Out:
# (37.29394243482891, -77.06787988773452, 20.17716732406511, -0.4697524629765225)
