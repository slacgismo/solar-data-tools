# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from solardatatools import DataHandler

# %%
df = pd.read_csv('timeseries.csv', index_col=0, parse_dates=True)

# %%
dh = DataHandler(df)

# %%
dh.run_pipeline(verbose=True)
# Out:
# total time: 10.31 seconds
# --------------------------------
# Breakdown
# --------------------------------
# Preprocessing              1.45s
# Cleaning                   2.60s
# Filtering/Summarizing      6.26s
#     Data quality           0.06s
#     Clear day detect       0.09s
#     Clipping detect        5.82s
#     Capacity change detect 0.29s

# %%
dh.plot_heatmap('raw');
